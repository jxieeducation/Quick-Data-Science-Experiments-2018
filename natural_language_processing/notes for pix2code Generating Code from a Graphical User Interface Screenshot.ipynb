# %% [markdown]
# [src](https://arxiv.org/pdf/1705.07962.pdf)

# %%
from IPython.display import Image
Image("pics/pix2code_arch.png")

# %% [markdown]
# * comparable to image captioning

# %%
Image("pics/pix2code_data.png")

# %% [markdown]
# ## arch
# * standard CNN
# * produced a custom DSL, so that the words in the screenshot doesn't matter and the DSL will contain the text
# * DSL makes it possible to one hot encode and not do an embedding
# * decoder is a char RNN that takes the concactenated CNN + RNN (DSL) embeddings
